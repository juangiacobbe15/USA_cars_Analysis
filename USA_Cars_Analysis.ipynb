# %% [markdown]
# <a href="https://colab.research.google.com/github/juangiacobbe15/USA_cars_Analysis/blob/main/USA_Cars_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello world')
# Out:
# hello world
